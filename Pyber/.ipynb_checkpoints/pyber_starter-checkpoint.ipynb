# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# File to Load (Remember to change these)
city_data = pd.read_csv("data/city_data.csv")
ride_data = pd.read_csv("data/ride_data.csv")

# Combine the data into a single dataset
combined_data =  pd.merge(ride_data, city_data,
                                 on = "city", how ="outer")
combined_data.head()
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2018-01-14 10:14:22  13.83  5739410935873
# 1  Lake Jonathanshire  2018-04-07 20:51:11  31.25  4441251834598
# 2  Lake Jonathanshire  2018-03-09 23:45:55  19.89  2389495660448
# 3  Lake Jonathanshire  2018-04-07 18:09:21  24.28  7796805191168
# 4  Lake Jonathanshire  2018-01-02 14:14:50  13.89   424254840012
#
#    driver_count   type
# 0             5  Urban
# 1             5  Urban
# 2             5  Urban
# 3             5  Urban
# 4             5  Urban

# %%
#x = avg_fare and y= total_rides
avg_fare = combined_data.groupby("city")["fare"].mean()
total_rides = combined_data.groupby("city")["ride_id"].count()
#total drivers per city to correlate bubble size on scatter plot
total_drivers = combined_data.groupby("city")["driver_count"].median()

# %%
print(avg_fare)
print(total_rides)
print(total_drivers)
# Out:
# city
# Amandaburgh             24.641667
# Barajasview             25.332273
# Barronchester           36.422500
# Bethanyland             32.956111
# Bradshawfurt            40.064000
# Brandonfort             35.437368
# Carriemouth             28.314444
# Christopherfurt         24.501852
# Colemanland             30.894545
# Davidfurt               31.995882
# Deanville               25.842632
# East Aaronbury          25.661111
# East Danielview         31.560588
# East Kaylahaven         23.757931
# East Kentstad           29.823077
# East Marymouth          30.835185
# Erikaland               24.906667
# Garzaport               24.123333
# Grahamburgh             25.221200
# Grayville               27.763333
# Harringtonfort          33.470000
# Huntermouth             28.993750
# Hurleymouth             25.891429
# Jerryton                25.649200
# Jessicaport             36.013333
# Johnton                 26.785714
# Joneschester            22.289600
# ...

# %%
#number of drivers per type
city_type = city_data.set_index('city')['type']
city_type.value_counts()
# Out:
# Urban       66
# Suburban    36
# Rural       18
# Name: type, dtype: int64

# %% [markdown]
# ## Bubble Plot of Ride Sharing Data

# %%
#storing all of this into a new dataframe to begin plotting
new_df = pd.DataFrame({"Average Fare per City":avg_fare,
                 "Number of Rides": total_rides,
                 "Number of Drivers": total_drivers,
                 "City Type": city_type
})
new_df.head()
# Out:
#                Average Fare per City  Number of Rides  Number of Drivers  \
# Amandaburgh                24.641667               18                 12
# Barajasview                25.332273               22                 26
# Barronchester              36.422500               16                 11
# Bethanyland                32.956111               18                 22
# Bradshawfurt               40.064000               10                  7
#
#               City Type
# Amandaburgh       Urban
# Barajasview       Urban
# Barronchester  Suburban
# Bethanyland    Suburban
# Bradshawfurt      Rural

# %%
#urban
urban = new_df.loc[new_df["City Type"]== "Urban"]

#suburban
suburban = new_df.loc[new_df["City Type"]== "Suburban"]

#rural
rural = new_df.loc[new_df["City Type"]== "Rural"]

# %%
plt.scatter(urban["Number of Rides"], urban["Average Fare per City"], color = "lightcoral", edgecolors="black", s = urban["Number of Drivers"]*16, label = "Urban", alpha = 0.65, linewidths= 0.5)
plt.scatter(suburban["Number of Rides"], suburban["Average Fare per City"], color = "lightskyblue", edgecolors = "black", s = suburban["Number of Drivers"]*16, label = "Suburban", alpha = 0.65, linewidths= 0.5)
plt.scatter(rural["Number of Rides"], rural["Average Fare per City"], color = "gold", edgecolors = "black", s = rural["Number of Drivers"]*16, label = "Rural", alpha = 0.65, linewidths= 0.5)

#Labels and Legend
plt.title("Pyber Ride Sharing Data (2016)")
plt.xlabel("Total Number of Rides (Per City)")
plt.ylabel("Average Fare ($)")
plt.text(45, 30,"Note: Circle size correlates with driver count per city.")
plt.grid()

#Legend with changing the legend handles size
lgnd = plt.legend(loc="best", scatterpoints=1, fontsize=10)
lgnd.legendHandles[0]._sizes = [30]
lgnd.legendHandles[1]._sizes = [30]
lgnd.legendHandles[2]._sizes = [30]

plt.savefig("../Output Images/Pyber Plot.png")

# %% [markdown]
# ## Total Fares by City Type

# %%
# Calculate Type Percents
total_fare = combined_data.groupby("type")["fare"].sum()
fare_type = total_fare.keys()

# %%
colors = ["gold", "lightskyblue","lightcoral"]
explode = (0,0,0.1)
# Build Pie Chart
fare_pie = plt.pie(total_fare, explode = explode, colors = colors,labels = fare_type, autopct="%1.1f%%", shadow=True, startangle=160)
plt.title("% of Total Fare by City Type")
plt.axis("equal")
plt.tight_layout()
plt.show()
# Save Figure
plt.savefig("../Output Images/Fares by City.png")

# %% [markdown]
# ## Total Rides by City Type

# %%
total_rides = combined_data.groupby("type")["ride_id"].count()
rides_type = total_rides.keys()

# %%
colors = ["gold", "lightskyblue","lightcoral"]
explode = (0,0,0.15)
# Build Pie Chart
rides_pie = plt.pie(total_rides, explode = explode, colors = colors,labels = rides_type, autopct="%1.1f%%", shadow=True, startangle=160)
plt.title("% of Total Rides by City Type")
plt.axis("equal")
plt.tight_layout()
plt.show()
# Save Figure
plt.savefig("../Output Images/Rides by City.png")

# %% [markdown]
# ## Total Drivers by City Type

# %%
total_drivers = new_df.groupby("City Type")["Number of Drivers"].sum()
drivers_type = total_drivers.keys()

# %%
colors = ["gold", "lightskyblue","lightcoral"]
explode = (0,0,0.1)
# Build Pie Chart
drivers_pie = plt.pie(total_drivers, explode = explode, colors = colors,labels = drivers_type, autopct="%1.1f%%", shadow=True, startangle=160)
plt.title("% of Total Drivers by City Type")
plt.axis("equal")
plt.tight_layout()
plt.show()
plt.savefig("../Output Images/Drivers by City.png")
# Save Figure
